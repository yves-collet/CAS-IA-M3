# %%
# %sql
/* Find the managed location under Catalog >> dbw_<name>_dataplatform_dev_001 >> Details >> Storage root*/
CREATE CATALOG IF NOT EXISTS yvescollet_lakehouse MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragebwltj3or2wvay.dfs.core.windows.net/7405619394184652';
