-- %%
SELECT c.LastName, SUM(soh.TotalDue) AS total_revenue 
FROM saleslt.SalesOrderHeader soh INNER JOIN saleslt.Customer c ON soh.CustomerID = c.CustomerID
GROUP BY c.LastName 
ORDER BY total_revenue DESC LIMIT 3;
